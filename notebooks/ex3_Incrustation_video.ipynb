# %% [markdown]
# <img
#     src="https://upload.wikimedia.org/wikipedia/commons/4/42/CNAM_Logo.svg"
#     alt=""
#     height="200px"
#     width="200px"
#     align=left
# />
#
#
# <center> <br>
#   <h1 style="color:#7c7979";>Incrustation et display d'une vidéo à l'intérieur d'un carnet Jupyter</h1>
# </center>

# %% [markdown]
# ## 1) Vidéo locale
# Ci-dessous l'insertion d'une vidéo locale (.mp4) de démonstration de l'interface JupyterLab

# %%
from IPython.display import Video

Video("video_decouverte_Jupyter_Lab.mp4")
# Out:
# <video src="video_decouverte_Jupyter_Lab.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## 2) Vidéo Youtube
#
# Ci-dessous l'insertion d'une vidéo youtube présentant l'interface Jupyter et l'utilisation des carnets Jupyter

# %%
from IPython.display import YouTubeVideo

video = YouTubeVideo('Duicsycntdo')
display(video)
